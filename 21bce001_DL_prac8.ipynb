# %%
import torch
import torch.nn as nn
from torch import optim
from torch.utils.data import Dataset, DataLoader, random_split
from io import open
import unicodedata
import re

# %%
if torch.cuda.is_available():
    device=torch.device(type='cuda', index=0)
else:
    device=torch.device(type='cpu', index=0)

print(f'Using device {device}')
# Out:
# Using device cuda:0

# %%
#unicode 2 ascii, remove non-letter characters, trim
def normalizeString(s): 
    sres=""
    for ch in unicodedata.normalize('NFD', s): 
        #Return the normal form form ('NFD') for the Unicode string s.
        if unicodedata.category(ch) != 'Mn':
            # The function in the first part returns the general 
            # category assigned to the character ch as string. 
            # "Mn' refers to Mark, Nonspacing
            sres+=ch
    sres = re.sub(r"([.!?])", r" \1", sres) 
    # inserts a space before any occurrence of ".", "!", or "?" in the string sres. 
    sres = re.sub(r"[^a-zA-Z!?]+", r" ", sres) 
    # this line of code replaces any sequence of characters in sres 
    # that are not letters (a-z or A-Z) or the punctuation marks 
    # "!" or "?" with a single space character.
    return sres.strip()

#create list of pairs (list of lists) (no filtering)
def createNormalizedPairs():
    initpairs=[]
    for pair in data:
        s1,s2=pair.split('\t')
        s1=normalizeString(s1.lower().strip())
        s2=normalizeString(s2.lower().strip())
        initpairs.append([s1,s2])
    #print(len(initpairs))
    return initpairs

#filter pairs
max_length = 10
def filterPairs(initpairs):
    #filtering conditions in addition to max_length
    eng_prefixes = (
        "i am ", "i m ",
        "he is", "he s ",
        "she is", "she s ",
        "you are", "you re ",
        "we are", "we re ",
        "they are", "they re "
    )

    pairs=[]
    for pair in initpairs:
        if len(pair[0].split(" ")) < max_length and len(pair[1].split(" ")) < max_length and pair[0].lower().startswith(eng_prefixes):
            pairs.append(pair)

    print("Number of pairs after filtering:", len(pairs))
    return pairs #list of lists

# %%
class Vocab:
    def __init__(self, name):
        self.name=name
        self.word2index={'SOS':0, 'EOS':1}
        self.index2word={0:'SOS', 1:'EOS'}
        self.word2count={}
        self.nwords=2
    
    def buildVocab(self,s):
        for word in s.split(" "):
            if word not in self.word2index:
                self.word2index[word]=self.nwords
                self.index2word[self.nwords]=word
                self.word2count[word]=1
                self.nwords+=1
            else:
                self.word2count[word]+=1

# %%
class Encoder(nn.Module):
    def __init__(self, input_size, embed_size, hidden_size, dropout_p=0.1):
        super().__init__()
        self.e=nn.Embedding(input_size, embed_size)
        self.dropout=nn.Dropout(dropout_p)
        self.gru=nn.GRU(embed_size,hidden_size, batch_first=True)
    
    def forward(self,x):
        x=self.e(x)
        x=self.dropout(x)
        outputs, hidden=self.gru(x)
        return outputs, hidden

# %%
class Decoder(nn.Module):
    def __init__(self,output_size,embed_size,hidden_size):
        super().__init__()
        self.e=nn.Embedding(output_size,embed_size)
        self.relu=nn.ReLU()
        self.gru=nn.GRU(embed_size, hidden_size, batch_first=True)
        self.lin=nn.Linear(hidden_size,output_size)
        self.lsoftmax=nn.LogSoftmax(dim=-1)
    
    def forward(self,x,prev_hidden):
        x=self.e(x)
        x=self.relu(x)
        output,hidden=self.gru(x,prev_hidden)
        y=self.lin(output)
        y=self.lsoftmax(y)
        return y, hidden

# %%
def get_input_ids(sentence,langobj):
    input_ids=[]
    for word in sentence.split(" "):
        input_ids.append(langobj.word2index[word])
    
    if langobj.name=='fre': #translation-direction sensitive
        input_ids.append(langobj.word2index['EOS'])
    else:
        input_ids.insert(0,langobj.word2index['SOS'])
        input_ids.append(langobj.word2index['EOS'])
    return torch.tensor(input_ids)

# %%
class CustomDataset(Dataset):
    def __init__(self):
        super().__init__()
    
    def __len__(self):
        return length
    
    def __getitem__(self,idx):
        t=pairs[idx][0] #translation-direction sensitive
        s=pairs[idx][1] #translation-direction sensitive
        s_input_ids=torch.zeros(max_length+1, dtype=torch.int64)
        t_input_ids=torch.zeros(max_length+2, dtype=torch.int64)
        s_input_ids[:len(s.split(" "))+1]=get_input_ids(s,fre) #translation-direction sensitive
        t_input_ids[:len(t.split(" "))+2]=get_input_ids(t,eng) #translation-direction sensitive
        
        return s_input_ids, t_input_ids

# %%
def train_one_epoch():
    encoder.train()
    decoder.train()
    track_loss=0
    
    for i, (s_ids,t_ids) in enumerate(train_dataloader):
        s_ids=s_ids.to(device)
        t_ids=t_ids.to(device)
        encoder_outputs, encoder_hidden=encoder(s_ids)
        decoder_hidden=encoder_hidden
        yhats, decoder_hidden = decoder(t_ids[:,0:-1],decoder_hidden)
                    
        gt=t_ids[:,1:]
        
        yhats_reshaped=yhats.view(-1,yhats.shape[-1])
        
        gt=gt.reshape(-1)
        
        
        loss=loss_fn(yhats_reshaped,gt)
        track_loss+=loss.item()
        
        opte.zero_grad()
        optd.zero_grad()
        
        loss.backward()
        
        opte.step()
        optd.step()
        
    return track_loss/len(train_dataloader)

# %%
def ids2Sentence(ids,vocab):
    sentence=""
    for id in ids.squeeze():
        if id==0:
            continue
        word=vocab.index2word[id.item()]
        sentence+=word + " "
        if id==1:  
            break
    return sentence

# %%
#eval loop (written assuming batch_size=1)
def eval_one_epoch(e,n_epochs):
    encoder.eval()
    decoder.eval()
    track_loss=0
    with torch.no_grad():
        for i, (s_ids,t_ids) in enumerate(test_dataloader):
            s_ids=s_ids.to(device)
            t_ids=t_ids.to(device)
            encoder_outputs, encoder_hidden=encoder(s_ids)
            decoder_hidden=encoder_hidden #n_dim=3
            input_ids=t_ids[:,0]
            yhats=[]
            if e+1==n_epochs:
                pred_sentence=""
            for j in range(1,max_length+2): #j starts from 1
                probs, decoder_hidden = decoder(input_ids.unsqueeze(1),decoder_hidden)
                yhats.append(probs)
                _,input_ids=torch.topk(probs,1,dim=-1)
                input_ids=input_ids.squeeze(1,2) #still a tensor
                if e+1==n_epochs:
                    word=eng.index2word[input_ids.item()] #batch_size=1
                    pred_sentence+=word + " "
                if input_ids.item() == 1: #batch_size=1
                    break
                                
            if e+1==n_epochs:
                src_sentence=ids2Sentence(s_ids,fre) #translation-direction sensitive
                gt_sentence=ids2Sentence(t_ids[:,1:],eng) #translation-direction sensitive

                print("\n-----------------------------------")
                print("Source Sentence:",src_sentence)
                print("GT Sentence:",gt_sentence)
                print("Predicted Sentence:",pred_sentence)
            
            yhats_cat=torch.cat(yhats,dim=1)
            yhats_reshaped=yhats_cat.view(-1,yhats_cat.shape[-1])
            gt=t_ids[:,1:j+1]
            gt=gt.view(-1)
            

            loss=loss_fn(yhats_reshaped,gt)
            track_loss+=loss.item()
            
        if e+1==n_epochs:    
            print("-----------------------------------")
        return track_loss/len(test_dataloader)

# %%
#driver code

#read data
data=open("/kaggle/input/eng-fra/eng-fra.txt").read().strip().split('\n')
print("Total number of pairs:",len(data))

#create pairs (create + normalize)
initpairs=createNormalizedPairs() #list of lists. Each inner list is a pair

#filter pairs
pairs=filterPairs(initpairs)
length=len(pairs)

#create Vocab objects for each language
eng=Vocab('eng')
fre=Vocab('fre')

#build the vocab
for pair in pairs:
    eng.buildVocab(pair[0])
    fre.buildVocab(pair[1])

#print vocab size
print("English Vocab Length:",eng.nwords)
print("French Vocab Length:",fre.nwords)    
    
dataset=CustomDataset()
train_dataset,test_dataset=random_split(dataset,[0.99,0.01])

batch_size=32
train_dataloader=DataLoader(dataset=train_dataset,batch_size=batch_size, shuffle=False)
test_dataloader=DataLoader(dataset=test_dataset,batch_size=1, shuffle=False)

    
embed_size=300
hidden_size=512

encoder=Encoder(fre.nwords,embed_size,hidden_size).to(device) #translation-direction sensitive
decoder=Decoder(eng.nwords,embed_size,hidden_size).to(device) #translation-direction sensitive

loss_fn=nn.NLLLoss(ignore_index=0).to(device)
lr=0.001
opte=optim.Adam(params=encoder.parameters(), lr=lr, weight_decay=0.001)
optd=optim.Adam(params=decoder.parameters(), lr=lr, weight_decay=0.001)

n_epochs=80

for e in range(n_epochs):
    print("Epoch=",e+1, sep="", end=", ")
    print("Train Loss=", round(train_one_epoch(),4), sep="", end=", ")
    print("Eval Loss=",round(eval_one_epoch(e,n_epochs),4), sep="")
# Out:
# Total number of pairs: 135842
# Number of pairs after filtering: 11445
# English Vocab Length: 2991
# French Vocab Length: 4601
# Epoch=1, Train Loss=3.1455, Eval Loss=3.4373
# Epoch=2, Train Loss=2.3968, Eval Loss=3.1169
# Epoch=3, Train Loss=2.1571, Eval Loss=2.8849
# Epoch=4, Train Loss=2.0365, Eval Loss=2.7919
# Epoch=5, Train Loss=1.9634, Eval Loss=2.7005
# Epoch=6, Train Loss=1.914, Eval Loss=2.6888
# Epoch=7, Train Loss=1.8664, Eval Loss=2.5019
# Epoch=8, Train Loss=1.8219, Eval Loss=2.3599
# Epoch=9, Train Loss=1.7805, Eval Loss=2.3376
# Epoch=10, Train Loss=1.7352, Eval Loss=2.3319
# Epoch=11, Train Loss=1.6939, Eval Loss=2.3716
# Epoch=12, Train Loss=1.6522, Eval Loss=2.3173
# Epoch=13, Train Loss=1.6191, Eval Loss=2.1812
# Epoch=14, Train Loss=1.5781, Eval Loss=2.2088
# Epoch=15, Train Loss=1.5509, Eval Loss=2.1708
# Epoch=16, Train Loss=1.5253, Eval Loss=2.1575
# Epoch=17, Train Loss=1.4973, Eval Loss=2.1922
# Epoch=18, Train Loss=1.4721, Eval Loss=2.1058
# Epoch=19, Train Loss=1.4519, Eval Loss=2.1896
# Epoch=20, Train Loss=1.4344, Eval Loss=2.1557
# Epoch=21, Train Loss=1.4084, Eval Loss=2.1599
# Epoch=22, Train Loss=1.4036, Eval Loss=2.1058
# Epoch=23, Train Loss=1.3805, Eval Loss=2.1559
# Epoch=24, Train Loss=1.3693, Eval Loss=2.0813
# Epoch=25, Train Loss=1.3509, Eval Loss=2.0563
# Epoch=26, Train Loss=1.338, Eval Loss=2.0781
# Epoch=27, Train Loss=1.3349, Eval Loss=2.0346
# Epoch=28, Train Loss=1.3207, Eval Loss=1.9695
# Epoch=29, Train Loss=1.3096, Eval Loss=2.0977
# Epoch=30, Train Loss=1.2995, Eval Loss=2.0417
# Epoch=31, Train Loss=1.2948, Eval Loss=2.0488
# Epoch=32, Train Loss=1.2901, Eval Loss=2.0162
# Epoch=33, Train Loss=1.2853, Eval Loss=1.9704
# Epoch=34, Train Loss=1.2727, Eval Loss=1.9529
# Epoch=35, Train Loss=1.263, Eval Loss=1.982
# Epoch=36, Train Loss=1.2593, Eval Loss=2.0665
# Epoch=37, Train Loss=1.2598, Eval Loss=2.0173
# Epoch=38, Train Loss=1.2565, Eval Loss=1.9694
# Epoch=39, Train Loss=1.2451, Eval Loss=1.9627
# Epoch=40, Train Loss=1.2445, Eval Loss=2.0001
# Epoch=41, Train Loss=1.2375, Eval Loss=1.9981
# Epoch=42, Train Loss=1.2369, Eval Loss=1.9441
# Epoch=43, Train Loss=1.2339, Eval Loss=1.8851
# Epoch=44, Train Loss=1.2332, Eval Loss=1.9532
# Epoch=45, Train Loss=1.221, Eval Loss=1.9593
# Epoch=46, Train Loss=1.2214, Eval Loss=1.8757
# Epoch=47, Train Loss=1.2194, Eval Loss=1.9443
# Epoch=48, Train Loss=1.2112, Eval Loss=1.9659
# Epoch=49, Train Loss=1.2093, Eval Loss=1.9409
# Epoch=50, Train Loss=1.2108, Eval Loss=1.9754
# Epoch=51, Train Loss=1.2097, Eval Loss=1.9552
# Epoch=52, Train Loss=1.2068, Eval Loss=1.925
# Epoch=53, Train Loss=1.2036, Eval Loss=1.9254
# Epoch=54, Train Loss=1.1979, Eval Loss=1.9387
# Epoch=55, Train Loss=1.2039, Eval Loss=1.9361
# Epoch=56, Train Loss=1.1943, Eval Loss=1.9781
# Epoch=57, Train Loss=1.1933, Eval Loss=1.9375
# Epoch=58, Train Loss=1.1887, Eval Loss=1.8518
# Epoch=59, Train Loss=1.1939, Eval Loss=1.858
# Epoch=60, Train Loss=1.1866, Eval Loss=1.8981
# Epoch=61, Train Loss=1.1843, Eval Loss=1.9259
# Epoch=62, Train Loss=1.1847, Eval Loss=1.8727
# Epoch=63, Train Loss=1.1853, Eval Loss=1.804
# Epoch=64, Train Loss=1.1889, Eval Loss=1.9985
# Epoch=65, Train Loss=1.1835, Eval Loss=1.9459
# Epoch=66, Train Loss=1.1817, Eval Loss=1.8729
# Epoch=67, Train Loss=1.1746, Eval Loss=1.9716
# Epoch=68, Train Loss=1.1745, Eval Loss=1.8355
# Epoch=69, Train Loss=1.1743, Eval Loss=1.7814
# Epoch=70, Train Loss=1.176, Eval Loss=1.8686
# Epoch=71, Train Loss=1.1694, Eval Loss=1.9532
# Epoch=72, Train Loss=1.172, Eval Loss=1.9194
# Epoch=73, Train Loss=1.1686, Eval Loss=1.8687
# Epoch=74, Train Loss=1.1714, Eval Loss=1.8852
# Epoch=75, Train Loss=1.1678, Eval Loss=1.8533
# Epoch=76, Train Loss=1.1698, Eval Loss=1.9058
# Epoch=77, Train Loss=1.1675, Eval Loss=1.8078
# Epoch=78, Train Loss=1.1634, Eval Loss=1.8861
# Epoch=79, Train Loss=1.1648, Eval Loss=1.788
# Epoch=80, Train Loss=1.1571,
# -----------------------------------
# Source Sentence: nous sommes ici pour les aider EOS
# GT Sentence: we re here to help them EOS
# Predicted Sentence: they re here to help EOS
#
# -----------------------------------
# Source Sentence: je suis surprise que vous ignoriez cela EOS
# GT Sentence: i m surprised you didn t know that EOS
# Predicted Sentence: i m sorry i didn t hear you EOS
#
# -----------------------------------
# Source Sentence: vous le faites correctement EOS
# GT Sentence: you re doing it right EOS
# Predicted Sentence: you re doing it EOS
#
# -----------------------------------
# Source Sentence: nous fermons tot EOS
# GT Sentence: we re closing early EOS
# Predicted Sentence: we re up early EOS
#
# -----------------------------------
# Source Sentence: je ne reste pas EOS
# GT Sentence: i m not staying EOS
# Predicted Sentence: i m not staying EOS
#
# -----------------------------------
# Source Sentence: ils se sourient EOS
# GT Sentence: they re smiling at each other EOS
# Predicted Sentence: they re in at EOS
#
# -----------------------------------
# Source Sentence: je suis desole je ne vous ai pas entendue EOS
# GT Sentence: i m sorry i didn t hear you EOS
# Predicted Sentence: i m sorry i didn t hear you EOS
#
# -----------------------------------
# Source Sentence: il est bien apprecie EOS
# GT Sentence: he is well liked EOS
# Predicted Sentence: he s kind of everyone EOS
#
# -----------------------------------
# Source Sentence: vous etes le maitre EOS
# GT Sentence: you re the master EOS
# Predicted Sentence: you re the master EOS
#
# -----------------------------------
# Source Sentence: elle trouve toujours des defauts a son mari EOS
# GT Sentence: she is always finding fault with her husband EOS
# Predicted Sentence: she is always dependent with her EOS
#
# -----------------------------------
# Source Sentence: nous sommes toutes pretes EOS
# GT Sentence: we are all set EOS
# Predicted Sentence: we re all ready EOS
#
# -----------------------------------
# Source Sentence: je viens de portugal EOS
# GT Sentence: i am from portugal EOS
# Predicted Sentence: i m from a college EOS
#
# -----------------------------------
# Source Sentence: j y vais maintenant EOS
# GT Sentence: i m going there now EOS
# Predicted Sentence: i m going EOS
#
# -----------------------------------
# Source Sentence: ta chance est epuisee EOS
# GT Sentence: you re out of luck EOS
# Predicted Sentence: you re out of her EOS
#
# -----------------------------------
# Source Sentence: je suis votre s ur EOS
# GT Sentence: i m your sister EOS
# Predicted Sentence: i m your partner EOS
#
# -----------------------------------
# Source Sentence: vous etes assez mignons quand vous etes en colere EOS
# GT Sentence: you re kind of cute when you re mad EOS
# Predicted Sentence: you re kind of cute when you re mad EOS
#
# -----------------------------------
# Source Sentence: je suis occupe je ne peux donc y aller EOS
# GT Sentence: i m busy so i can t go EOS
# Predicted Sentence: i m tired tired i am out now EOS
#
# -----------------------------------
# Source Sentence: ils sont sur le point de partir EOS
# GT Sentence: they re about to leave EOS
# Predicted Sentence: they are about to go EOS
#
# -----------------------------------
# Source Sentence: je me rejouis de vous revoir EOS
# GT Sentence: i am looking forward to seeing you again EOS
# Predicted Sentence: i m glad to see you again EOS
#
# -----------------------------------
# Source Sentence: c est vraiment un homme de parole EOS
# GT Sentence: he is indeed a man of his word EOS
# Predicted Sentence: he is a very man man EOS
#
# -----------------------------------
# Source Sentence: nous allons avoir a travailler ensemble EOS
# GT Sentence: we re going to have to work together EOS
# Predicted Sentence: we re going to have tom tom EOS
#
# -----------------------------------
# Source Sentence: nous sommes tres serieuses EOS
# GT Sentence: we re very serious EOS
# Predicted Sentence: we re very serious EOS
#
# -----------------------------------
# Source Sentence: nous ne sommes pas ici pour t arreter EOS
# GT Sentence: we are not here to arrest you EOS
# Predicted Sentence: we re not here to you you EOS
#
# -----------------------------------
# Source Sentence: c est un scientifique EOS
# GT Sentence: he is a scientist EOS
# Predicted Sentence: he is a student EOS
#
# -----------------------------------
# Source Sentence: elle a beaucoup de succes aupres des garcons EOS
# GT Sentence: she is very popular among the boys EOS
# Predicted Sentence: she is very sensitive of the dark EOS
#
# -----------------------------------
# Source Sentence: je suis excite a l idee du demenagement EOS
# GT Sentence: i m excited about the move EOS
# Predicted Sentence: i m familiar of the world of nature EOS
#
# -----------------------------------
# Source Sentence: je suis a court de munitions EOS
# GT Sentence: i m out of ammo EOS
# Predicted Sentence: i m out of time EOS
#
# -----------------------------------
# Source Sentence: je ne suis plus ainsi EOS
# GT Sentence: i m not like that anymore EOS
# Predicted Sentence: i m not so anymore EOS
#
# -----------------------------------
# Source Sentence: je ne suis pas arme EOS
# GT Sentence: i m not armed EOS
# Predicted Sentence: i m not armed EOS
#
# -----------------------------------
# Source Sentence: je suis desolee je n ai pas saisi cela EOS
# GT Sentence: i m sorry i didn t catch that EOS
# Predicted Sentence: i m sorry i don t hear you EOS
#
# -----------------------------------
# Source Sentence: je suis implique EOS
# GT Sentence: i m involved EOS
# Predicted Sentence: i m involved EOS
#
# -----------------------------------
# Source Sentence: tu n es pas censee etre la dedans EOS
# GT Sentence: you re not supposed to be in here EOS
# Predicted Sentence: you re not supposed to be in here EOS
#
# -----------------------------------
# Source Sentence: tu es le seul a pouvoir m aider EOS
# GT Sentence: you re the only one who can help me EOS
# Predicted Sentence: you re the only one who can help me EOS
#
# -----------------------------------
# Source Sentence: j economise pour acheter une nouvelle voiture EOS
# GT Sentence: i m saving up to buy a new car EOS
# Predicted Sentence: i m looking a much from you EOS
#
# -----------------------------------
# Source Sentence: je vais dire ca a tom EOS
# GT Sentence: i m going to tell tom that EOS
# Predicted Sentence: i m going to do tom tom EOS
#
# -----------------------------------
# Source Sentence: j ai toujours faim EOS
# GT Sentence: i m still hungry EOS
# Predicted Sentence: i m always hungry EOS
#
# -----------------------------------
# Source Sentence: je conte une histoire EOS
# GT Sentence: i am telling a story EOS
# Predicted Sentence: i m a very time EOS
#
# -----------------------------------
# Source Sentence: je le rends EOS
# GT Sentence: i m giving it back EOS
# Predicted Sentence: i m in it EOS
#
# -----------------------------------
# Source Sentence: tu es probablement fatiguee EOS
# GT Sentence: you re probably tired EOS
# Predicted Sentence: you re probably tired EOS
#
# -----------------------------------
# Source Sentence: je suis enfant unique EOS
# GT Sentence: i am an only child EOS
# Predicted Sentence: i m a only child EOS
#
# -----------------------------------
# Source Sentence: tu triches EOS
# GT Sentence: you re cheating EOS
# Predicted Sentence: you re looking EOS
#
# -----------------------------------
# Source Sentence: nous n y allons pas si ? EOS
# GT Sentence: we re not going are we ? EOS
# Predicted Sentence: we re not tired are you ? EOS
#
# -----------------------------------
# Source Sentence: vous etes la seule a pouvoir m aider EOS
# GT Sentence: you re the only one who can help me EOS
# Predicted Sentence: you re the only one i can help me EOS
#
# -----------------------------------
# Source Sentence: elles sont tres bienveillantes EOS
# GT Sentence: they are very kind EOS
# Predicted Sentence: they re very very looking EOS
#
# -----------------------------------
# Source Sentence: vous etes fort curieuses EOS
# GT Sentence: you re very curious EOS
# Predicted Sentence: you re very very EOS
#
# -----------------------------------
# Source Sentence: ils sont tous ici EOS
# GT Sentence: they re all here EOS
# Predicted Sentence: they re all here EOS
#
# -----------------------------------
# Source Sentence: elles sont toutes en train d attendre EOS
# GT Sentence: they re all waiting EOS
# Predicted Sentence: they re not looking for you EOS
#
# -----------------------------------
# Source Sentence: il est tres talentueux EOS
# GT Sentence: he is very talented EOS
# Predicted Sentence: he s very talented EOS
#
# -----------------------------------
# Source Sentence: ce sont des garcons EOS
# GT Sentence: they re boys EOS
# Predicted Sentence: they re in the science EOS
#
# -----------------------------------
# Source Sentence: il n est pas aussi malin que mon frere EOS
# GT Sentence: he is not as clever as my brother EOS
# Predicted Sentence: he is not as smart as me EOS
#
# -----------------------------------
# Source Sentence: je la vois ce soir EOS
# GT Sentence: i m seeing her this evening EOS
# Predicted Sentence: i m going EOS
#
# -----------------------------------
# Source Sentence: j en ai assez de l anglais EOS
# GT Sentence: i m fed up with english EOS
# Predicted Sentence: i m interested in english EOS
#
# -----------------------------------
# Source Sentence: ils cherchent une maison ou habiter EOS
# GT Sentence: they are looking for a house to live in EOS
# Predicted Sentence: they re looking for a job EOS
#
# -----------------------------------
# Source Sentence: quelle menteuse tu fais ! EOS
# GT Sentence: you re such a liar EOS
# Predicted Sentence: you re such a liar EOS
#
# -----------------------------------
# Source Sentence: nous sommes tous deux ecrivains EOS
# GT Sentence: we re both writers EOS
# Predicted Sentence: we re both both EOS
#
# -----------------------------------
# Source Sentence: elle est habituee a vivre seule EOS
# GT Sentence: she is used to living alone EOS
# Predicted Sentence: she is used to living alone EOS
#
# -----------------------------------
# Source Sentence: nous sommes confrontes a un tas de problemes EOS
# GT Sentence: we are faced with a host of problems EOS
# Predicted Sentence: we are faced with a lot of problems EOS
#
# -----------------------------------
# Source Sentence: je suis beni EOS
# GT Sentence: i m blessed EOS
# Predicted Sentence: i m thorough EOS
#
# -----------------------------------
# Source Sentence: elle s en sort tres bien EOS
# GT Sentence: she s getting on all right EOS
# Predicted Sentence: she is very very very very dress EOS
#
# -----------------------------------
# Source Sentence: tu es la meilleure EOS
# GT Sentence: you re the best EOS
# Predicted Sentence: you re the same EOS
#
# -----------------------------------
# Source Sentence: ce sont ceux qui veulent s y rendre EOS
# GT Sentence: they are the ones who want to go EOS
# Predicted Sentence: they are the one who want to go EOS
#
# -----------------------------------
# Source Sentence: toutes ces disputes commencent a me fatiguer EOS
# GT Sentence: i m growing tired of all this arguing EOS
# Predicted Sentence: i m always tired of this EOS
#
# -----------------------------------
# Source Sentence: tu es aveugle par l amour EOS
# GT Sentence: you are blinded by love EOS
# Predicted Sentence: you are blinded by love EOS
#
# -----------------------------------
# Source Sentence: elle est toujours au bas de la classe EOS
# GT Sentence: she is always at the bottom of the class EOS
# Predicted Sentence: she is always in the dress EOS
#
# -----------------------------------
# Source Sentence: je suis sur que tout se passera bien EOS
# GT Sentence: i m sure everything will be ok EOS
# Predicted Sentence: i m sure everything will will fine EOS
#
# -----------------------------------
# Source Sentence: je suis pret quand tu l es EOS
# GT Sentence: i m ready when you are EOS
# Predicted Sentence: i m ready if you are EOS
#
# -----------------------------------
# Source Sentence: il est tres courageux EOS
# GT Sentence: he is very brave EOS
# Predicted Sentence: he is very brave EOS
#
# -----------------------------------
# Source Sentence: j attends toujours ta reponse EOS
# GT Sentence: i m still waiting for your answer EOS
# Predicted Sentence: i m looking for for your job EOS
#
# -----------------------------------
# Source Sentence: j adore prendre des photos EOS
# GT Sentence: i m fond of taking pictures EOS
# Predicted Sentence: i m very fond of you EOS
#
# -----------------------------------
# Source Sentence: je suis prete ! EOS
# GT Sentence: i m ready ! EOS
# Predicted Sentence: i m ready ! EOS
#
# -----------------------------------
# Source Sentence: nous avons toutes faim EOS
# GT Sentence: we re all hungry EOS
# Predicted Sentence: we re all hungry EOS
#
# -----------------------------------
# Source Sentence: je vais quitter mon emploi actuel EOS
# GT Sentence: i am going to leave my present job EOS
# Predicted Sentence: i m going to be him EOS
#
# -----------------------------------
# Source Sentence: je suis heureux pour vous deux EOS
# GT Sentence: i m happy for you both EOS
# Predicted Sentence: i m very happy for you EOS
#
# -----------------------------------
# Source Sentence: il est toujours celibataire EOS
# GT Sentence: he s still single EOS
# Predicted Sentence: he is still dead EOS
#
# -----------------------------------
# Source Sentence: je vais dormir EOS
# GT Sentence: i m going to sleep EOS
# Predicted Sentence: i m going to bed EOS
#
# -----------------------------------
# Source Sentence: vous etes tres occupe EOS
# GT Sentence: you re very busy EOS
# Predicted Sentence: you re very busy EOS
#
# -----------------------------------
# Source Sentence: on m a promu EOS
# GT Sentence: i m being promoted EOS
# Predicted Sentence: we re being serious EOS
#
# -----------------------------------
# Source Sentence: il regarde la television EOS
# GT Sentence: he is watching tv EOS
# Predicted Sentence: he is watching a tv EOS
#
# -----------------------------------
# Source Sentence: vous etes tres curieuses EOS
# GT Sentence: you re very curious EOS
# Predicted Sentence: you re very sophisticated EOS
#
# -----------------------------------
# Source Sentence: je commence des ce soir EOS
# GT Sentence: i am starting this evening EOS
# Predicted Sentence: i m going to this up this EOS
#
# -----------------------------------
# Source Sentence: je suis satisfait de sa performance EOS
# GT Sentence: i m pleased with his performance EOS
# Predicted Sentence: i m pleased with his performance EOS
#
# -----------------------------------
# Source Sentence: vous etes celui qui m a forme EOS
# GT Sentence: you re the one who trained me EOS
# Predicted Sentence: you re the one who trained me EOS
#
# -----------------------------------
# Source Sentence: elles vont a la guerre EOS
# GT Sentence: they re going to the war EOS
# Predicted Sentence: they re back back EOS
#
# -----------------------------------
# Source Sentence: je suis chez moi tom EOS
# GT Sentence: i m home tom EOS
# Predicted Sentence: i m at tom s house EOS
#
# -----------------------------------
# Source Sentence: je vis avec ma maman maintenant EOS
# GT Sentence: i m living with my mom now EOS
# Predicted Sentence: i m staying with my new with i am EOS
#
# -----------------------------------
# Source Sentence: tu n es plus en prise avec la realite EOS
# GT Sentence: you re out of touch with reality EOS
# Predicted Sentence: you re not wasting with with shoes EOS
#
# -----------------------------------
# Source Sentence: vous etes en premier EOS
# GT Sentence: you re first EOS
# Predicted Sentence: you re in first EOS
#
# -----------------------------------
# Source Sentence: je suis plus qu heureuse EOS
# GT Sentence: i m more than happy EOS
# Predicted Sentence: i m very happy EOS
#
# -----------------------------------
# Source Sentence: je lui dis constamment de bien se comporter EOS
# GT Sentence: i m constantly telling her to behave herself EOS
# Predicted Sentence: i m looking looking her EOS
#
# -----------------------------------
# Source Sentence: tu es sans pitie EOS
# GT Sentence: you re ruthless EOS
# Predicted Sentence: you re incorrigible EOS
#
# -----------------------------------
# Source Sentence: tu es tout a fait attirante EOS
# GT Sentence: you re quite attractive EOS
# Predicted Sentence: you re all dead EOS
#
# -----------------------------------
# Source Sentence: je ne suis pas sure de la raison EOS
# GT Sentence: i m not sure why EOS
# Predicted Sentence: i m not sure sure EOS
#
# -----------------------------------
# Source Sentence: nous en sommes tres satisfaites EOS
# GT Sentence: we re very satisfied with it EOS
# Predicted Sentence: we re very happy EOS
#
# -----------------------------------
# Source Sentence: je ne suis pas un bon menteur EOS
# GT Sentence: i m not a good liar EOS
# Predicted Sentence: i m not a good liar EOS
#
# -----------------------------------
# Source Sentence: je n en suis pas trop convaincue EOS
# GT Sentence: i m not too convinced EOS
# Predicted Sentence: i m not convinced in this EOS
#
# -----------------------------------
# Source Sentence: elle n est pas poete mais romanciere EOS
# GT Sentence: she is not a poet but a novelist EOS
# Predicted Sentence: she is not a am than i am EOS
#
# -----------------------------------
# Source Sentence: il est riche et puissant EOS
# GT Sentence: he s rich and powerful EOS
# Predicted Sentence: he is a and and EOS
#
# -----------------------------------
# Source Sentence: il hume la soupe EOS
# GT Sentence: he is smelling the soup EOS
# Predicted Sentence: he s got the manager EOS
#
# -----------------------------------
# Source Sentence: je le fais pour toi EOS
# GT Sentence: i m doing this for you EOS
# Predicted Sentence: i m doing you EOS
#
# -----------------------------------
# Source Sentence: on ne l invite pas aux fetes EOS
# GT Sentence: she s not invited to parties EOS
# Predicted Sentence: we re not invited to invited EOS
#
# -----------------------------------
# Source Sentence: nous sommes influences par notre environnement EOS
# GT Sentence: we are influenced by our environment EOS
# Predicted Sentence: we are aware with our children EOS
#
# -----------------------------------
# Source Sentence: elle l ecoute EOS
# GT Sentence: she is listening to him EOS
# Predicted Sentence: she is listening EOS
#
# -----------------------------------
# Source Sentence: elle s inquiete pour ses examens EOS
# GT Sentence: she s worrying about her exams EOS
# Predicted Sentence: she is worried about her job EOS
#
# -----------------------------------
# Source Sentence: nous n en avons pas fini EOS
# GT Sentence: we re not finished EOS
# Predicted Sentence: we re not done EOS
#
# -----------------------------------
# Source Sentence: tu as vraiment beaucoup de chance EOS
# GT Sentence: you re very fortunate EOS
# Predicted Sentence: you re really very lucky EOS
#
# -----------------------------------
# Source Sentence: nous n y sommes pas pretes EOS
# GT Sentence: we re not ready for this EOS
# Predicted Sentence: we re not ready EOS
#
# -----------------------------------
# Source Sentence: elles sont plutot marrantes EOS
# GT Sentence: they re kind of fun EOS
# Predicted Sentence: they re very kind EOS
#
# -----------------------------------
# Source Sentence: nous aurons une nouvelle voiture le mois prochain EOS
# GT Sentence: we re getting a new car next month EOS
# Predicted Sentence: you re having the new time time EOS
#
# -----------------------------------
# Source Sentence: nous sommes tous en danger EOS
# GT Sentence: we re all at risk EOS
# Predicted Sentence: we re not in danger EOS
#
# -----------------------------------
# Source Sentence: je suis trop occupe pour l aider EOS
# GT Sentence: i m too busy to help her EOS
# Predicted Sentence: i m not busy for tom EOS
#
# -----------------------------------
# Source Sentence: nous nous aimons EOS
# GT Sentence: we re in love EOS
# Predicted Sentence: we re back EOS
#
# -----------------------------------
# Source Sentence: je craque EOS
# GT Sentence: i m cracking up EOS
# Predicted Sentence: i m punctual EOS
#
# -----------------------------------
# Source Sentence: je suis dans le petrin EOS
# GT Sentence: i am in a spot EOS
# Predicted Sentence: i m in trouble EOS
#
# -----------------------------------
# Source Sentence: je suis desole de devoir te laisser seul EOS
# GT Sentence: i m sorry i had to leave you alone EOS
# Predicted Sentence: i m sorry to have bothered you EOS
# -----------------------------------
# Eval Loss=1.8409
